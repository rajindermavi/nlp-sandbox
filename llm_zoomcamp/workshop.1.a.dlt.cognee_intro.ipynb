# %%
from datetime import datetime
import os

import requests

import pandas as pd

import dlt

import cognee
from cognee.shared.logging_utils import get_logger, ERROR
from cognee.api.v1.visualize.visualize import visualize_graph
from cognee.api.v1.search import SearchType
from cognee.modules.engine.models import NodeSet
# Out:
# 2025-07-07T02:06:02.740985 [info     ] Logging initialized            [cognee.shared.logging_utils] cognee_version=0.2.0 os_info='Linux 6.11.0-26-generic (#26~24.04.1-Ubuntu SMP PREEMPT_DYNAMIC Thu Apr 17 19:20:47 UTC 2)' python_version=3.12.3 structlog_version=25.4.0
#
# 2025-07-07T02:06:02.742003 [info     ] Want to learn more? Visit the Cognee documentation: https://docs.cognee.ai [cognee.shared.logging_utils]
#
# HTTP Request: GET https://raw.githubusercontent.com/BerriAI/litellm/main/model_prices_and_context_window.json "HTTP/1.1 200 OK"

# %%
from dotenv import load_dotenv

load_dotenv()

cognee.config.set_llm_api_key(os.getenv('OPENAI_API_KEY'))
os.environ["GRAPH_DATABASE_PROVIDER"] = "kuzu"

# %%
# Step 1: Create DLT resource
@dlt.resource(write_disposition="replace", name="zoomcamp_data")
def zoomcamp_data():
    url = "https://us-central1-dlthub-analytics.cloudfunctions.net/data_engineering_zoomcamp_api"
    response = requests.get(url)
    data = response.json()

    # Convert to DataFrame
    df = pd.DataFrame(data)
    df['Trip_Pickup_DateTime'] = pd.to_datetime(df['Trip_Pickup_DateTime'])

    # Define buckets
    df['tag'] = pd.cut(
        df['Trip_Pickup_DateTime'],
        bins=[
            pd.Timestamp("2009-06-01"),
            pd.Timestamp("2009-06-10"),
            pd.Timestamp("2009-06-20"),
            pd.Timestamp("2009-06-30")
        ],
        labels=["first_10_days", "second_10_days", "last_10_days"],
        right=False
    )

    # Drop rows not in the specified range
    df = df[df['tag'].notnull()]
    yield df

# Step 2: Create and run the pipeline
pipeline = dlt.pipeline(
    pipeline_name="zoomcamp_pipeline",
    destination="duckdb",
    dataset_name="zoomcamp_tagged_data"
)
load_info = pipeline.run(zoomcamp_data())
print(pipeline.last_trace)
# Out:
# 2025-07-06 19:06:10,973|[WARNING]|319823|136521811320960|dlt|logger.py|wrapper:24|In schema `zoomcamp`: The following columns in table 'zoomcamp_data' did not receive any data during this load and therefore could not have their types inferred:
#   - rate_code
#   - mta_tax
#
# Unless type hints are provided, these columns will not be materialized in the destination.
# One way to provide type hints is to use the 'columns' argument in the '@dlt.resource' decorator.  For example:
#
# @dlt.resource(columns={'rate_code': {'data_type': 'text'}})
# Run started at 2025-07-07 02:06:08.250062+00:00 and COMPLETED in 2.95 seconds with 4 steps.
# Step extract COMPLETED in 2.58 seconds.
#
# Load package 1751853968.3890276 is EXTRACTED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step normalize COMPLETED in 0.03 seconds.
# Normalized data for the following tables:
# - zoomcamp_data: 998 row(s)
#
# Load package 1751853968.3890276 is NORMALIZED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step load COMPLETED in 0.22 seconds.
# Pipeline zoomcamp_pipeline load step completed in 0.19 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset zoomcamp_tagged_data
# The duckdb destination used duckdb:////home/rajinder-mavi/code/nlp_sandbox/llm_zoomcamp/zoomcamp_pipeline.duckdb location to store data
# Load package 1751853968.3890276 is LOADED and contains no failed jobs
#
# Step run COMPLETED in 2.95 seconds.
# Pipeline zoomcamp_pipeline load step completed in 0.19 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset zoomcamp_tagged_data
# The duckdb destination used duckdb:////home/rajinder-mavi/code/nlp_sandbox/llm_zoomcamp/zoomcamp_pipeline.duckdb location to store data
# Load package 1751853968.3890276 is LOADED and contains no failed jobs

# %%
dataset = pipeline.dataset().zoomcamp_data.df()

dataset
# Out:
#        end_lat    end_lon  fare_amt  passenger_count payment_type  start_lat  \
# 0    40.742963 -73.980072      45.0                1       Credit  40.641525
# 1    40.740187 -74.005698       6.5                1       Credit  40.722065
# 2    40.718043 -74.004745      12.5                5       Credit  40.761945
# 3    40.739637 -73.985233       4.9                1         CASH  40.749802
# 4    40.730032 -73.852693      25.7                1         CASH  40.776825
# ..         ...        ...       ...              ...          ...        ...
# 993  40.742998 -73.919065       6.9                1         CASH  40.743523
# 994  40.731953 -73.985330       7.3                1         CASH  40.733143
# 995  40.712640 -73.998870       5.7                1         CASH  40.711865
# 996  40.732998 -74.007113       7.3                2         CASH  40.744658
# 997  40.767120 -73.953602       4.5                5         CASH  40.778478
#
#      start_lon  tip_amt  tolls_amt  total_amt  trip_distance  \
# 0   -73.787442      9.0       4.15      58.15          17.52
# 1   -74.009767      1.0       0.00       8.50           1.56
# 2   -73.983038      2.0       0.00      15.50           3.37
# 3   -73.992247      0.0       0.00       5.40           1.11
# 4   -73.949233      0.0       4.15      29.85          11.09
# ..         ...      ...        ...        ...            ...
# 993 -73.918735      0.0       0.00       6.90           1.83
# 994 -74.006408      0.0       0.00       7.80           1.59
# 995 -74.010158      0.0       0.00       5.70           0.79
# 996 -73.992063      0.0       0.00       7.80           1.87
# 997 -73.945387      0.0       0.00       4.50           0.91
#
#     trip_dropoff_date_time trip_pickup_date_time  store_and_forward  \
# 0      2009-06-14 23:48:00   2009-06-14 23:23:00                NaN
# 1      2009-06-18 17:43:00   2009-06-18 17:35:00                NaN
# 2      2009-06-10 18:27:00   2009-06-10 18:08:00                NaN
# 3      2009-06-14 23:58:00   2009-06-14 23:54:00                NaN
# 4      2009-06-13 13:23:00   2009-06-13 13:01:00                NaN
# ..                     ...                   ...                ...
# 993    2009-06-10 06:23:00   2009-06-10 06:16:00                NaN
# 994    2009-06-10 05:11:00   2009-06-10 05:02:00                NaN
# 995    2009-06-13 12:45:00   2009-06-13 12:37:00                NaN
# 996    2009-06-09 21:34:00   2009-06-09 21:25:00                NaN
# 997    2009-06-13 08:59:00   2009-06-13 08:56:00                NaN
#
#      surcharge vendor_name             tag
# 0          0.0         VTS  second_10_days
# 1          1.0         VTS  second_10_days
# 2          1.0         VTS  second_10_days
# 3          0.5         VTS  second_10_days
# 4          0.0         VTS  second_10_days
# ..         ...         ...             ...
# 993        0.0         VTS  second_10_days
# 994        0.5         VTS  second_10_days
# 995        0.0         VTS  second_10_days
# 996        0.5         VTS   first_10_days
# 997        0.0         VTS  second_10_days
#
# [998 rows x 17 columns]

# %%
dataset["tag"].value_counts()
# Out:
# tag
# first_10_days     481
# second_10_days    295
# last_10_days      222
# Name: count, dtype: int64

# %%
async def main():
    await cognee.prune.prune_data()
    await cognee.prune.prune_system(metadata=True)

    # Add the first 10 days
    df_set1 = dataset.loc[dataset["tag"] == "first_10_days"]
    df_set1.drop(columns=["tag"], inplace=True)
    df_set1 = df_set1.to_json(orient="records", lines=False)
    await cognee.add(df_set1, node_set=["first_10_days"])

    # Add the second 10 days
    df_set2 = dataset.loc[dataset["tag"] == "second_10_days"]
    df_set2.drop(columns=["tag"], inplace=True)
    df_set2 = df_set2.to_json(orient="records", lines=False)
    await cognee.add(df_set2, node_set=["second_10_days"])

    # Add the last 10 days
    df_set3 = dataset.loc[dataset["tag"] == "last_10_days"]
    df_set3.drop(columns=["tag"], inplace=True)
    df_set3 = df_set3.to_json(orient="records", lines=False)
    await cognee.add(df_set3, node_set=["last_10_days"])

    await cognee.cognify()

    visualization_path = "artifacts/graph_visualization.html"
    await visualize_graph(visualization_path)

# %%
await main()
# Out:
# 2025-07-07T02:06:11.935468 [info     ] Cleared all data from graph while preserving structure [cognee.shared.logging_utils]
# 2025-07-07T02:06:11.966582 [info     ] Deleted Kuzu database files at /home/rajinder-mavi/code/nlp_sandbox/.venv/lib/python3.12/site-packages/cognee/.cognee_system/databases/cognee_graph_kuzu [cognee.shared.logging_utils]
# 2025-07-07T02:06:12.691112 [info     ] Database deleted successfully. [cognee.shared.logging_utils]/tmp/ipykernel_319823/1629198782.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_set1.drop(columns=["tag"], inplace=True)
#
# Langfuse client is disabled since no public_key was provided as a parameter or environment variable 'LANGFUSE_PUBLIC_KEY'. See our docs: https://langfuse.com/docs/sdk/python/low-level-sdk#initialize-client19:06:13 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:06:14 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# EmbeddingRateLimiter initialized: enabled=False, requests_limit=60, interval_seconds=6019:06:14 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:06:15 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large
# 2025-07-07T02:06:15.470388 [info     ] Pipeline run started: `146ea502-50bd-5c97-994f-2c0dfc93c74f` [run_tasks(tasks: [Task], data)]
# User 664676e7-9087-466e-ae88-07ae56e6589a has registered.
# 2025-07-07T02:06:15.772064 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
# 2025-07-07T02:06:16.147109 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
# 2025-07-07T02:06:17.170116 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
# 2025-07-07T02:06:17.577180 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
# 2025-07-07T02:06:18.185546 [info     ] Pipeline run completed: `146ea502-50bd-5c97-994f-2c0dfc93c74f` [run_tasks(tasks: [Task], data)]/tmp/ipykernel_319823/1629198782.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_set2.drop(columns=["tag"], inplace=True)
#
# 2025-07-07T02:06:18.691760 [info     ] Pipeline run started: `146ea502-50bd-5c97-994f-2c0dfc93c74f` [run_tasks(tasks: [Task], data)]
# 2025-07-07T02:06:19.103793 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
# 2025-07-07T02:06:19.366008 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
# 2025-07-07T02:06:20.144004 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
# 2025-07-07T02:06:20.435951 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
# 2025-07-07T02:06:20.736063 [info     ] Pipeline run completed: `146ea502-50bd-5c97-994f-2c0dfc93c74f` [run_tasks(tasks: [Task], data)]/tmp/ipykernel_319823/1629198782.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_set3.drop(columns=["tag"], inplace=True)
#
# 2025-07-07T02:06:21.028504 [info     ] Pipeline run started: `146ea502-50bd-5c97-994f-2c0dfc93c74f` [run_tasks(tasks: [Task], data)]
# 2025-07-07T02:06:21.297026 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
# 2025-07-07T02:06:21.574466 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
# 2025-07-07T02:06:22.028978 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
# 2025-07-07T02:06:22.271030 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
# 2025-07-07T02:06:22.512380 [info     ] Pipeline run completed: `146ea502-50bd-5c97-994f-2c0dfc93c74f` [run_tasks(tasks: [Task], data)]
# 2025-07-07T02:06:22.797666 [info     ] Ontology file 'None' not found. No owl ontology will be attached to the graph. [OntologyAdapter]
# 2025-07-07T02:06:22.821267 [info     ] Pipeline run started: `0cfc4034-bca2-58a4-a60a-815634b51102` [run_tasks(tasks: [Task], data)]
# 2025-07-07T02:06:23.050329 [info     ] Coroutine task started: `classify_documents` [run_tasks_base]
# 2025-07-07T02:06:23.354253 [info     ] Coroutine task started: `check_permissions_on_dataset` [run_tasks_base]
# 2025-07-07T02:06:23.597879 [info     ] Async Generator task started: `extract_chunks_from_documents` [run_tasks_base]
# 2025-07-07T02:06:24.161922 [info     ] Coroutine task started: `extract_graph_from_data` [run_tasks_base]19:06:24 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:06:24 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:06:24 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:06:24 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:06:24 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:06:24 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:06:24 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:06:24 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:06:24 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:06:24 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:06:33 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:06:33 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:06:33 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:06:33 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:06:34 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:06:34 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:06:34 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:06:34 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:06:34 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:06:34 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:06:35 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:06:35 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:06:35 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:06:35 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:06:43 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:06:43 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:07:02 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:07:02 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:21 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:21 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# 2025-07-07T02:08:21.989954 [info     ] No close match found for 'vendor' in category 'classes' [OntologyAdapter]
# 2025-07-07T02:08:21.995639 [info     ] No close match found for 'vts' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:21.997106 [info     ] No close match found for 'payment type' in category 'classes' [OntologyAdapter]
# 2025-07-07T02:08:22.000509 [info     ] No close match found for 'cash' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.001970 [info     ] No close match found for 'credit' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.006393 [info     ] No close match found for 'date' in category 'classes' [OntologyAdapter]
# 2025-07-07T02:08:22.010242 [info     ] No close match found for '2009-06-21' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.013672 [info     ] No close match found for '2009-06-20' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.017977 [info     ] No close match found for '2009-06-27' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.019724 [info     ] No close match found for '2009-06-28' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.024527 [info     ] No close match found for '2009-06-24' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.025620 [info     ] No close match found for '2009-06-26' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.026983 [info     ] No close match found for '2009-06-29' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.031120 [info     ] No close match found for 'taxivendor' in category 'classes' [OntologyAdapter]
# 2025-07-07T02:08:22.033558 [info     ] No close match found for 'paymenttype' in category 'classes' [OntologyAdapter]
# 2025-07-07T02:08:22.034482 [info     ] No close match found for '2009-06-25' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.035480 [info     ] No close match found for '2009-06-23' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.036401 [info     ] No close match found for '2009-06-15' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.037433 [info     ] No close match found for 'cmt' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.038305 [info     ] No close match found for 'june 22, 2009' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.039809 [info     ] No close match found for '2009-06-20 22:59:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.040850 [info     ] No close match found for '2009-06-20 18:56:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.042384 [info     ] No close match found for '2009-06-20 21:49:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.043677 [info     ] No close match found for '2009-06-20 20:08:15' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.045104 [info     ] No close match found for '2009-06-20 10:06:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.046066 [info     ] No close match found for '2009-06-20 09:45:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.047402 [info     ] No close match found for '2009-06-20 19:57:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.048159 [info     ] No close match found for '2009-06-20 09:47:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.048821 [info     ] No close match found for '2009-06-20 09:37:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.049845 [info     ] No close match found for '2009-06-20 19:44:13' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.050490 [info     ] No close match found for '2009-06-20 06:49:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.051363 [info     ] No close match found for '2009-06-20 21:28:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22
in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.148878 [info     ] No close match found for 'trip 27' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.149808 [info     ] No close match found for 'trip 28' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.151310 [info     ] No close match found for 'trip 29' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.152580 [info     ] No close match found for 'trip 30' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.153754 [info     ] No close match found for 'trip 31' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.154681 [info     ] No close match found for 'trip 32' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.156423 [info     ] No close match found for 'trip 33' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.157269 [info     ] No close match found for 'trip 34' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.158063 [info     ] No close match found for 'trip 35' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.159449 [info     ] No close match found for 'trip 36' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.160283 [info     ] No close match found for 'trip 37' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.161245 [info     ] No close match found for 'trip 38' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.162125 [info     ] No close match found for 'trip 39' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.163215 [info     ] No close match found for 'trip 40' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.164689 [info     ] No close match found for 'trip 41' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.165594 [info     ] No close match found for 'trip 42' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.166427 [info     ] No close match found for 'trip 43' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.167154 [info     ] No close match found for 'trip 44' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.167855 [info     ] No close match found for 'trip 45' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.168726 [info     ] No close match found for 'trip 46' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.169601 [info     ] No close match found for 'trip 47' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.171018 [info     ] No close match found for 'trip 48' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.171933 [info     ] No close match found for 'trip 49' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.173331 [info     ] No close match found for 'trip 50' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.174518 [info     ] No close match found for 'trip 51' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.176169 [info     ] No close match found for 'trip 52' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.177127 [info     ] No close match found for 'trip 53' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:08:22.182319 [info     ] No close match found for '2009-06-01' in category 'individuals' [OntologyAdapter]19:08:23 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:08:25 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:08:26 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:08:26 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:08:27 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:08:28 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large
# 2025-07-07T02:08:28.548937 [info     ] Coroutine task started: `summarize_text` [run_tasks_base]19:08:28 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:08:28 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:08:28 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:08:28 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:08:28 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:08:28 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:08:28 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:08:28 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:08:28 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:08:28 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:08:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:31 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:31 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:32 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:32 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:32 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:32 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:32 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:32 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:32 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:32 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# 2025-07-07T02:08:32.422179 [info     ] Coroutine task started: `add_data_points` [run_tasks_base]19:08:33 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:08:34 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:08:36 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:08:36 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:08:37 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:08:37 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:08:38 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large
# 2025-07-07T02:08:38.796821 [info     ] Coroutine task completed: `add_data_points` [run_tasks_base]
# 2025-07-07T02:08:39.495334 [info     ] Coroutine task completed: `summarize_text` [run_tasks_base]
# 2025-07-07T02:08:39.950813 [info     ] Coroutine task completed: `extract_graph_from_data` [run_tasks_base]
# 2025-07-07T02:08:40.464159 [info     ] Coroutine task started: `extract_graph_from_data` [run_tasks_base]19:08:40 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:08:40 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:08:40 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:08:40 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:08:40 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:08:40 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:08:41 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:08:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:50 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:50 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:51 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:51 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:51 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:51 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:56 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:08:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:04 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:04 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:22 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:22 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# 2025-07-07T02:09:22.248641 [info     ] No close match found for 'vendor' in category 'classes' [OntologyAdapter]
# 2025-07-07T02:09:22.249823 [info     ] No close match found for 'vts' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.250950 [info     ] No close match found for 'paymenttype' in category 'classes' [OntologyAdapter]
# 2025-07-07T02:09:22.252251 [info     ] No close match found for 'cash' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.253337 [info     ] No close match found for 'credit' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.254100 [info     ] No close match found for 'date' in category 'classes' [OntologyAdapter]
# 2025-07-07T02:09:22.255033 [info     ] No close match found for '2009-06-01' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.255614 [info     ] No close match found for '2009-06-02' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.256520 [info     ] No close match found for '2009-06-03' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.257261 [info     ] No close match found for '2009-06-04' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.257969 [info     ] No close match found for '2009-06-05' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.258665 [info     ] No close match found for '2009-06-06' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.259352 [info     ] No close match found for '2009-06-07' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.260258 [info     ] No close match found for '2009-06-08' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.261306 [info     ] No close match found for '2009-06-09' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.262736 [info     ] No close match found for 'company' in category 'classes' [OntologyAdapter]
# 2025-07-07T02:09:22.263817 [info     ] No close match found for 'payment type' in category 'classes' [OntologyAdapter]
# 2025-07-07T02:09:22.266218 [info     ] No close match found for '2009-06-14' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.267749 [info     ] No close match found for '2009-06-18' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.268600 [info     ] No close match found for '2009-06-10' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.269517 [info     ] No close match found for '2009-06-11' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.270391 [info     ] No close match found for '2009-06-16' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.271070 [info     ] No close match found for '2009-06-13' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.272404 [info     ] No close match found for '2009-06-12' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.273348 [info     ] No close match found for '2009-06-15' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.274790 [info     ] No close match found for '2009-06-19' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22
in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.354931 [info     ] No close match found for 'trip instance 39' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.355927 [info     ] No close match found for 'trip instance 40' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.356792 [info     ] No close match found for 'trip instance 41' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.357927 [info     ] No close match found for 'trip instance 42' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.359365 [info     ] No close match found for 'trip instance 43' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.360772 [info     ] No close match found for 'trip instance 44' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.361796 [info     ] No close match found for 'trip instance 45' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.362804 [info     ] No close match found for 'trip instance 46' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.364717 [info     ] No close match found for 'trip instance 47' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.366824 [info     ] No close match found for 'trip instance 48' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.369373 [info     ] No close match found for 'trip instance 49' in category 'individuals' [OntologyAdapter]
# 2025-07-07T02:09:22.370774 [info     ] No close match found for 'trip instance 50' in category 'individuals' [OntologyAdapter]19:09:24 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:25 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:25 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:26 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:27 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large
# 2025-07-07T02:09:27.600396 [info     ] Coroutine task started: `summarize_text` [run_tasks_base]19:09:27 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:09:27 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:09:27 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:09:28 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:09:28 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:09:28 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:09:28 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:09:29 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:29 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:29 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:29 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:29 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# 2025-07-07T02:09:30.553661 [info     ] Coroutine task started: `add_data_points` [run_tasks_base]19:09:31 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:32 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:34 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:34 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:35 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:36 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large
# 2025-07-07T02:09:36.576646 [info     ] Coroutine task completed: `add_data_points` [run_tasks_base]
# 2025-07-07T02:09:37.109480 [info     ] Coroutine task completed: `summarize_text` [run_tasks_base]
# 2025-07-07T02:09:37.552827 [info     ] Coroutine task completed: `extract_graph_from_data` [run_tasks_base]
# 2025-07-07T02:09:37.852168 [info     ] Async Generator task completed: `extract_chunks_from_documents` [run_tasks_base]
# 2025-07-07T02:09:38.146314 [info     ] Coroutine task completed: `check_permissions_on_dataset` [run_tasks_base]
# 2025-07-07T02:09:38.374881 [info     ] Coroutine task completed: `classify_documents` [run_tasks_base]
# 2025-07-07T02:09:38.623027 [info     ] Pipeline run completed: `0cfc4034-bca2-58a4-a60a-815634b51102` [run_tasks(tasks: [Task], data)]
# 2025-07-07T02:09:38.909533 [info     ] Graph visualization saved as artifacts/graph_visualization.html [cognee.shared.logging_utils]
# 2025-07-07T02:09:38.911078 [info     ] The HTML file has been stored at path: artifacts/graph_visualization.html [cognee.shared.logging_utils]

# %%
async def search_cognee(query, node_set, top_k = 5, query_type=SearchType.GRAPH_COMPLETION):
    answer = await cognee.search(
        query_text=query,
        query_type=query_type,
        node_type=NodeSet,
        node_name=node_set
    )
    return answer

# %%
results = await search_cognee(
    "What's in this knowledge graph?",
    node_set=["first_10_days"]
)
print(results[0])
# Out:
# 19:09:39 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:41 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:41 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:09:44 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:44 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# The knowledge graph contains data about trips on specific dates in June 2009, detailing trip pickup and drop-off times, locations (latitude and longitude), fare amounts, passenger counts, payment types, and associated vendor information. Key dates include June 2, 3, 4, 8, and 9, with connections indicating that various trip records are associated with these dates.

# %%
results = await search_cognee(
    "What kind of payment methods are there?",
    node_set=["first_10_days"]
)
print(results[0])
# Out:
# 19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:45 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:46 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:46 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:46 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:46 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:09:46 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:09:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:09:48 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# The payment methods available include cash, which is accepted by taxi service vendors (vts).
