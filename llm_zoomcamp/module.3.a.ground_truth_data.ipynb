# %%
import os
import random
import requests
import json
from collections import defaultdict
from uuid import uuid4
from tqdm.auto import tqdm
import pickle

import pandas as pd

from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()
# Out:
# True

# %%
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

openai_client = OpenAI(api_key=OPENAI_API_KEY)

# %%
#def generate_document_id(doc):
#    # combined = f"{doc['course']}-{doc['question']}"
#    combined = f"{doc['course']}-{doc['question']}-{doc['text'][:10]}"
#    hash_object = hashlib.md5(combined.encode())
#    hash_hex = hash_object.hexdigest()
#    document_id = hash_hex[:8]
#    return document_id
#
if os.path.exists('documents-with-ids.json'):
    with open('documents-with-ids.json', 'rt') as f_in:
        documents = json.load(f_in)
else:
    docs_url = 'https://github.com/DataTalksClub/llm-zoomcamp/blob/main/01-intro/documents.json?raw=1'
    docs_response = requests.get(docs_url)
    documents_raw = docs_response.json()

    documents = []

    for course in documents_raw:
        course_name = course['course']

        for doc in course['documents']:
            doc['course'] = course_name
            doc['id'] = str(uuid4())
            documents.append(doc)

    with open('documents-with-ids.json', 'wt') as f_out:
        json.dump(documents, f_out, indent=2)

# %%
prompt_template = """
You emulate a student who's taking our course.
Formulate 5 questions this student might ask based on a FAQ record. The record
should contain the answer to the questions, and the questions should be complete and not too short.
If possible, use as fewer words as possible from the record. 

The record:

section: {section}
question: {question}
answer: {text}

Output a JSON object with a single key "questions" whose value is a list of 5 questions, like:
{{"questions": ["Q1", "Q2", "Q3", "Q4", "Q5"]}}
Do not include any extra text, explanation, or formatting.
""".strip()

# %%
select_doc = random.choice(documents)

select_doc
# Out:
# {'text': 'If you’re running MLflow on a remote VM, you need to forward the port too like we did in Module 1 for Jupyter notebook port 8888. Simply connect your server to VS Code, as we did, and add 5000 to the PORT like in the screenshot:\nAdded by Sharon Ibejih\nIf you are running MLflow locally and 127.0.0.1:5000 shows a blank page navigate to localhost:5000 instead.',
#  'section': 'Module 2: Experiment tracking',
#  'question': 'MLflow URL (http://127.0.0.1:5000), doesn’t open.',
#  'course': 'mlops-zoomcamp',
#  'id': '23ab5ad7-424b-414d-ae7e-218aa95397b0'}

# %%
prompt = prompt_template.format(**select_doc)
print(prompt)
# Out:
# You emulate a student who's taking our course.
# Formulate 5 questions this student might ask based on a FAQ record. The record
# should contain the answer to the questions, and the questions should be complete and not too short.
# If possible, use as fewer words as possible from the record.
#
# The record:
#
# section: Module 2: Experiment tracking
# question: MLflow URL (http://127.0.0.1:5000), doesn’t open.
# answer: If you’re running MLflow on a remote VM, you need to forward the port too like we did in Module 1 for Jupyter notebook port 8888. Simply connect your server to VS Code, as we did, and add 5000 to the PORT like in the screenshot:
# Added by Sharon Ibejih
# If you are running MLflow locally and 127.0.0.1:5000 shows a blank page navigate to localhost:5000 instead.
#
# Output a JSON object with a single key "questions" whose value is a list of 5 questions, like:
# {"questions": ["Q1", "Q2", "Q3", "Q4", "Q5"]}
# Do not include any extra text, explanation, or formatting.

# %%
def generate_questions(doc):
    prompt = prompt_template.format(**doc)

    response = openai_client.chat.completions.create(
        model='gpt-4o',
        messages=[{"role": "user", "content": prompt}],
        response_format={"type": "json_object"}
    )
    json_response = response.choices[0].message.content
    json_response = json.loads(json_response)['questions']
    return json_response

# %%
if os.path.exists('results.bin'):
    with open('results.bin', 'rb') as f_in:
        results = pickle.load(f_in)
        
else:
    parsed_results = {}
    for doc in tqdm(documents): 
        doc_id = doc['id']
        questions = generate_questions(doc)
        parsed_results[doc_id] = questions

    with open('results.bin','wb') as f_out:
        pickle.dump(parsed_results, f_out, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
#   0%|          | 0/948 [00:00<?, ?it/s]

# %%
parsed_documents = {d['id']: d for d in documents}

# %%
final_results = []

for doc_id, questions in parsed_results.items():
    course = parsed_documents[doc_id]['course']
    for q in questions:
        final_results.append((q, course, doc_id))

# %%
df = pd.DataFrame(final_results, columns=['question', 'course', 'document'])
df.to_csv('ground-truth-data.csv', index=False)

df.head()
# Out:
#                                             question  \
# 0                        When will the course start?
# 1  What is the exact date and time the course beg...
# 2        How can I subscribe to the course calendar?
# 3         What should I do before the course begins?
# 4  Which platform should I join for course announ...
#
#                       course                              document
# 0  data-engineering-zoomcamp  a7d2342a-f84f-4e9a-8df5-693a11b0a676
# 1  data-engineering-zoomcamp  a7d2342a-f84f-4e9a-8df5-693a11b0a676
# 2  data-engineering-zoomcamp  a7d2342a-f84f-4e9a-8df5-693a11b0a676
# 3  data-engineering-zoomcamp  a7d2342a-f84f-4e9a-8df5-693a11b0a676
# 4  data-engineering-zoomcamp  a7d2342a-f84f-4e9a-8df5-693a11b0a676

# %%
parsed_results
# Out:
# {'a7d2342a-f84f-4e9a-8df5-693a11b0a676': ['When will the course start?',
#   'What is the exact date and time the course begins?',
#   'How can I subscribe to the course calendar?',
#   'What should I do before the course begins?',
#   'Which platform should I join for course announcements?'],
#  '5fa2407d-bbe6-46b4-920b-a9f44e25cd2e': ['What are the prerequisites for this course?',
#   'Where are the prerequisites listed?',
#   'Can you tell me about the course prerequisites?',
#   'How can I find the course prerequisites?',
#   'What do I need to know before starting this course?'],
#  '842f74bf-c5d7-40ac-9cc4-4299ea9697b5': ['Is it possible to enroll after the course has started?',
#   'Can I submit assignments without registering for the course initially?',
#   'Are there any deadlines for the final project submission after joining late?',
#   'What should I be cautious of if joining the course post start-date?',
#   'Can I delay all coursework until close to deadlines after joining the course late?'],
#  'f538dac6-f601-49f6-8639-b72642a33b6d': ['When will I get my confirmation email after enrolling in the bootcamp?',
#   'Is it necessary to wait for acceptance before beginning the course?',
#   'Do I have to be on a list to start submitting assignments?',
#   "What is the purpose of registration if it doesn't affect my participation?",
#   "If confirmation isn't needed, how do I know I'm enrolled?"],
#  'ffcde6aa-a2da-46bd-a217-7c267dbb4729': ['What steps should I take to prepare before the course begins?',
#   'Which tools need to be installed before starting the course?',
#   'How can I ensure I am ready for the course content?',
#   'What are the software requirements to begin the coursework?',
#   'Which prerequisites should I review before the course?'],
#  '1b104062-a36e-4d22-b720-0fa98e7ee290': ['How many Zoom Camps are held annually?',
#   'Is there only one live cohort for the Data-Engineering Zoomcamp each year?',
#   'Can I join a Zoomcamp outside of the live schedule?',
#   'When is the MLOps Zoomcamp held each year?',
#   'Is the Machine Learning Zoomcamp available from September to January?'],
#  '789f8fa9-60d4-409f-8760-937bdaf745bf': ['Is Mage AI replacing Prefect in the 2024 course?',
#   'Were the terraform videos updated for this cohort?',
#   'Which tool was used for orchestration in 2023?',
#   'Is Airflow used at all in the current course?',
#   'How does the 2024 course differ from 2023 in terms of content?'],
#  'afb860a6-0a2e-4fab-94b3-475b9385bef2': ['Can I access the course materials after it ends?',
#   'Is it possible to study at my own pace once the course is over?',
#   'Will the homework be available after the course concludes?',
#   'Am I allowed to prepare for the next cohort with past materials?',
#   'Can I begin working on my final project after the course finishes?'],
#  '9e2c55ab-5829-40ca-87e8-d464753fa9d9': ['Can I access support in self-paced mode?',
#   'Where should I search for answers before asking for help?',
#   'How can I efficiently search the Slack channel for answers?',
#   'Is the ZoomcampQABot always accurate?',
#   'What resource should I check before asking new questions?'],
#  'be727def-f1ac-4f5d-86e9-a01d3666f748': ['Which YouTube playlist contains the main course videos?',
#   'Where can I find the main course videos with thumbnails?',
#   'Is there a specific playlist for videos of a particular year?',
#   'How can I access the playlist from Slack?',
#   'What type of videos are included in the playlists apart from the main ones?'],
#  '74a6b2d6-6d8e-4744-b4d8-7c45e370b97f': ['How many weekly hours are advised for this course?',
#   'What is the weekly time commitment for this course depending on my experience?',
#   'How much weekly time should I plan for in this course?',
#   'Based on prior knowledge, how many weekly hours should I invest in this course?',
#   'What is the recommended weekly study time for this course?'],
#  'b675da68-d30f-4d28-b82e-5d429055b1e3': ['Is it possible to earn a certificate by completing the course independently at my own pace?',
#   'Can I obtain a certificate if I join a self-paced course and finish all the assignments?',
#   'If I enroll in a self-paced mode, will I be eligible for a course certificate?',
#   'Does the self-paced option provide a certificate upon successful completion?',
#   'Can I receive a completion certificate if I opt for a self-paced learning mode?'],
#  '85a1e152-0ad4-4f69-8f93-c1e12396b809': ['What platform do students use to watch the Office Hour sessions?',
#   'How are students able to ask questions during the workshop sessions?',
#   'Where will the video URL for the Office Hour be shared before it starts?',
#   "Why shouldn't students post their questions in the chat during live sessions?",
#   'What channel on YouTube will the Office Hour be streamed on?'],
#  'fff47d4b-2f81-46bf-90f3-1ab489c3ccfb': ['Will the office hours be accessible if I miss them?',
#   "Can I watch a recording of the workshop later if I can't join live?",
#   'Are the live sessions available for replay after they end?',
#   'Is it possible to view the office hours at a later time if I was absent?',
#   'Will there be a recording available for missed office sessions?'],
#  'e31eb3f8-783b-4500-91df-4b927eb0b7a6': ['Where can I find the latest deadlines for homework and projects?',
#   'How can I receive updates about deadline changes for assignments?',
#   'What should I check for any extensions on homework deadlines?',
#   'Is there a reliable source for up-to-date project deadlines?',
#   'How will I know if the homework deadline has been updated by the instructor?'],
#  'e48479a2-a6e1-47c7-8a18-131524a4c762': ['Can I turn in my homework after the deadline?',
#   'What happens if I submit homework late?',
#   'Is it possible to submit assignments past the due date?',
#   'Are there any penalties for late homework submissions?',
#   'Can I submit assignments after the due date if the form is open?'],
#  '15253668-0819-4a69-91ae-104113ccc568': ['What should I provide as the homework URL?',
#   'Where should my code be located for homework submission?',
#   'What repository platforms are acceptable for my homework link?',
#   'Can I use GitHub for submitting my homework?',
#   'How should my homework URL be presented?'],
#  'a056f4d4-3508-40fb-9ad2-86492905c4ee': ['How are points assigned for the homework on the course platform?',
#   'Where can I view my total points earned from different activities?',
#   'What is the leaderboard system for tracking course points?',
#   'Can we earn points by contributing to the FAQ section, and if so, how many?',
#   "How many points do we get for submitting a 'Learning in Public' link?"],
#  '67c66bfb-8226-48a4-9c24-aa9ca965eda9': ['How can I identify my position on the course leaderboard?',
#   'Is it possible to find out the name I am using on the leaderboard?',
#   'Where can I check or change my leaderboard display name?',
#   'What is the procedure to view my Display name for the leaderboard ranking?',
#   'How do I access the settings to edit my course profile and Display name?'],
#  '07567a80-c481-48d5-9825-e025c0a8dbc9': ['Is Python 3.9 the advised version for the course in 2024?',
#   'Should I use Python 3.10 or 3.9 for stability?',
#   'Will Python 3.11 function correctly in this course?',
#   'Why is Python 3.9 recommended for the course videos?',
#   'Are troubleshooting reasons why Python 3.9 is suggested?'],
#  'e8508168-1700-4f44-8513-9a1b69ea53ae': ['Should I set up my environment on my local machine or use a virtual solution like GitHub Codespaces?',
#   'What challenges might Windows users face when setting up a local environment?',
#   'How can I work on the boot camp from different locations if I have multiple devices?',
#   'Which option should I start with if I want to work on a local machine?',
#   'What are the initial steps if I choose to use a virtual machine environment?'],
#  '96e9a8ad-6a66-4354-9db5-85f3077d51fa': ['Can I use GitHub Codespaces for Linux resources in this course?',
#   'Does GitHub Codespaces come with tools like Docker and Python pre-installed?',
#   'Is it possible to access a GitHub repository using GitHub Codespaces?',
#   'Can I utilize GitHub Codespaces as an alternative to CLI?',
#   'Are tools like Docker Compose available in GitHub Codespaces?'],
#  'a1106bfb-8006-4679-9e5e-f4d9f0a3694a': ['Is it mandatory to use GitHub Codespaces?',
#   'Can I complete the course on my personal computer?',
#   'Are there alternative platforms to GitHub Codespaces?',
#   'Is GCP VM a required tool for this course?',
#   'Can I use my existing PostgreSQL setup for the course?'],
#  'e924ddf0-519d-4f6a-8c2c-a8565036b000': ['Do I need to use both GitHub Codespaces and GCP for this course?',
#   "Is it necessary to learn GCP if I'm already familiar with GitHub Codespaces?",
#   'Would setting up a local environment be enough for most of this course?',
#   'Why should I consider learning BigQuery for the course?',
#   'Is it better to focus on GitHub Codespaces or GCP for the end project?'],
#  '770bebe4-1de6-4df5-8fa6-5bd87963f35a': ['What should I do if I encounter issues connecting to a GCP VM on Windows using VSCode?',
#   'Where can I find Registry Values to change when facing connection problems to GCP VM via VSCode on Windows?',
#   'How can I access the Registry Editor on a Windows machine?',
#   'What steps are involved in opening the Run command window on a Windows computer?',
#   'What alternative solution exists for resolving GCP VM connection issues without changing registry values?'],
#  '86756579-2928-406b-b997-d8272d835fae': ['Why do we use GCP instead of AWS?',
#   'Can I use platforms other than GCP for the course?',
#   'What are the benefits of using GCP for this course?',
#   'Is a credit card required to sign up for a GCP free trial?',
#   'Why is BigQuery important in our course?'],
#  '2721b4b0-da0e-44bf-86bc-7925d72d0d6f': ['Do I need to cover costs for cloud resources during the course?',
#   'Is there a way to avoid expenses for cloud services while enrolled?',
#   'Am I required to pay for using cloud platforms in this program?',
#   'Can I utilize cloud services for free while participating in the course?',
#   'Is it possible to access cloud solutions without a fee in this class?'],
#  'a8d16585-ed7b-4b2d-bcbf-306a0f5ed9bb': ['Is it possible to complete the course without using any cloud services, and if so, how?',
#   'Are there any components of the course that must be run on GCP?',
#   'Can I use local alternatives for all course tasks instead of GCP?',
#   'Will there be any guidance provided for setting up a home lab to do the course locally?',
#   'Is BigQuery the only course component that requires cloud use?'],
#  'add2f9cb-905a-4a0b-bcc7-a4069a285233': ['Is it allowed to use AWS for the projects in this course?',
#   'What should I consider when adapting course information for AWS?',
#   'Are there specific challenges when seeking help with AWS compared to GCP?',
#   "Will my final project involving AWS be evaluated the same as those using the course's default tools?",
#   'Can I expect to find many AWS users among coursemates for support?'],
#  '23a144cf-1b1d-492c-8c10-deb3ead8277d': ['Are there any live sessions apart from the office hours?',
#   'Will there be more live calls during the course?',
#   'When can we expect additional zoom calls besides office hours?',
#   'Is there a plan for extra live discussions during the Capstone?',
#   'How will we know if there are extra sessions outside office hours?'],
#  'b99854df-0986-49e4-b3c6-834c47b0ed9c': ['What dataset is used for the NYC Trip project?',
#   'Is the NYC Trip dataset for January 2022 or 2021?',
#   'Are we using updated data for the NYC project?',
#   'Will we use last year’s NYC Trip data?',
#   'Has the NYC Trip data changed from last year?'],
#  'ee5fe4ab-f339-499e-86bf-c27bac2c7d9a': ['Has the 2022 repository been removed?',
#   'Where can I find the 2022 materials now?',
#   'Is there a new location for the 2022 content?',
#   'Are the 2022 resources still accessible?',
#   'What happened to the 2022 course materials?'],
#  '60565690-77ac-4632-af73-83e273f53bba': ['Is it possible to choose my own tools for the project?',
#   'Am I allowed to select a different tool for the project?',
#   'Can I implement Airflow for my project?',
#   'Are there any restrictions on tools used in the project?',
#   'Is choosing any tool permissible for the final project?'],
#  '47cec62a-9ff0-4825-bee1-3231ea0cd917': ['Can I substitute the default tool with an alternative like Airflow?',
#   'Is it okay to use AWS instead of the default GCP products?',
#   'May I choose Tableau in place of Metabase for my project?',
#   'If I use a different stack for the course, will support be provided?',
#   'Do I need to justify using a different tool in the capstone project?'],
#  'e09c4400-5a7d-4c46-b439-ce255063d1ac': ['What are some ways to contribute to the course materials?',
#   'Can we help improve the repository structure?',
#   'Is sharing the course with friends encouraged?',
#   'How can a Pull Request enhance the course content?',
#   'What does starring the repo help achieve?'],
#  '34ae6b79-c22f-4ab1-9d33-89edc7cda392': ['Does the course accommodate multiple operating systems?',
#   'Is Linux required for this course?',
#   'Can I use a Mac for this course?',
#   'Is it possible to complete the course using Windows?',
#   'Are all operating systems equally suitable for the course?'],
#  '87262fe0-839c-44fb-abc1-c56739be3a4f': ['How can Windows users run shell scripts in later modules?',
#   'Why is WSL recommended for Windows users starting the course?',
#   "What issues do Windows users face if they don't use WSL?",
#   'What modules specifically require the use of shell scripts?',
#   "Why can't Windows users proceed with git bash or MINGW64 for shell scripts?"],
#  'ca6b2bf2-92f1-451e-98ab-258fb9c083fb': ['Where can I find recommended readings?',
#   'Are there any suggestions for extra materials?',
#   'Is there a list of books to help with the course?',
#   'Can you guide me to more resources for learning?',
#   'Where do I access additional learning tools for the course?'],
#  '2ec7ab9f-9cb9-40bf-b808-b8d091ad9292': ['How many chances do I get for submitting a project?',
#   'What happens if I miss the first project deadline?',
#   'Is there a second attempt if I fail the project submission?',
#   'Can I resubmit a project if I am late the first time?',
#   'Will I have another opportunity if my first project attempt fails?'],
#  'aa52d608-7946-4786-92af-ce44259f103e': ['What initial steps should I take to address an issue independently before seeking external help?',
#   'How can I effectively use keyboard shortcuts to troubleshoot problems?',
#   'What online resources can assist in finding solutions to common technical errors?',
#   'Which details should I include when posting a question on Slack to get the most helpful response?',
#   'When encountering a recurring issue, how should I document and communicate the changes in the environment?'],
#  '3051beb6-081c-4e55-8cf2-43083aae20de': ['When is it appropriate to seek help with troubleshooting?',
#   'What information should I include when asking for help with coding issues?',
#   'What details about the environment should I share when seeking support?',
#   'How important is it to share the error and line number when asking questions?',
#   'Why should I mention unsuccessful attempts when asking for assistance?'],
#  '2d15b10c-e179-44dd-bcc8-1a3f4b49149f': ['What is the initial step to utilize GitHub for this course?',
#   'How can I locally access the instructors’ code for the course?',
#   'Where can I find guidance to create personal repositories for my notes?',
#   'What files should be excluded from being stored in a repository?',
#   'Is it safe to store passwords in a private git repository?'],
#  '44e6523c-8555-4d07-b445-4f56a1449db5': ["What should I do if I encounter 'Makefile:2: *** missing separator. Stop.'?",
#   'How do I resolve the error related to tabs in my document?',
#   'What is the solution if spaces are used instead of tabs in a Makefile document?',
#   'Why is it important to use tabs instead of spaces in a Makefile?',
#   'What steps should I follow if my Makefile is not working due to tabs being replaced by spaces?'],
#  '9dd0f700-469f-4e23-b8c4-02cc1cbfdc83': ['How can you open an HTML file from Linux on WSL 2 with a Windows browser?',
#   'What is the command to open a webpage using wslview?',
#   'How do you specify which browser wslview should use?',
#   'What should you install to open HTML files with a Windows browser from WSL?',
#   'How can you set the default browser for opening HTML files in WSL 2?'],
#  '42658019-e3a1-4cfa-884a-5966a8f2ed96': ['How can I set up Chrome Remote Desktop on a Debian Linux VM in Compute Engine?',
#   'What should I do if I encounter a 403 Forbidden error while downloading Yellow Taxi Trip Records from the TLC website?',
#   'Where can I find a backup for the 2021 Taxi Data - Yellow Taxi Trip Records?',
#   'What is the correct link to download the 2021 January Yellow Trip Data from the backup?',
#   'How do I properly unzip a gz file since the unzip command does not work for it?'],
#  '6ee2e240-5a92-45eb-883e-050cfdd130e0': ['What should I do if my taxi data files are in *.csv.gz format?',
#   'How can I store taxi data files correctly if they are available as csv.gz?',
#   "What is an alternative to using csv_name = 'output.csv' for taxi data?",
#   'How can I extract the file name from the taxi data URL for proper storage?',
#   'Can pandas read csv.gz files directly using read_csv?'],
#  '900523ea-8054-4290-b7a7-66e2e7865785': ['Where can I find the data dictionary for Yellow Taxi trip data in NYC?',
#   'What is the URL for the data dictionary of Green Taxi trip records in NYC?',
#   'How do I access the NYC Yellow Taxi trip records data dictionary?',
#   'Which document contains the data dictionary for NYC Green Taxi trips?',
#   'Where is the link to the data dictionary for NYC Yellow Taxi trips located?'],
#  '20f2276b-f692-426f-beb7-350a92aa6ba3': ['How do I unzip a downloaded parquet file in the command line?',
#   'What is the command to convert a parquet file to CSV using a Python script?',
#   'Where should I add the line to define the parquet_name in ingest_data.py?',
#   'How do I download a file using wget and assign it a specific name?',
#   'Which function is used to read a parquet file into a DataFrame in pandas?'],
#  '46c27400-ca49-4d4f-a3b6-f379ddc27641': ["How can I install wget on Ubuntu if it's not recognized?",
#   'What is the easiest way to install wget on MacOS?',
#   'How do I get wget to work on Windows using Chocolatey?',
#   'Is there an alternative method to wget for downloading files in Python?',
#   'Where can I download the latest wget binary for Windows?'],
#  'd8fc30d0-65f8-4a9d-8f22-e0ab502c928d': ['How do I handle a certificate verification error with wget on MacOS in Jupyter Notebook?',
#   'What command modification should I use in CLI to bypass certificate validation for wget?',
#   'How can the Python library wget help when facing wget certificate issues?',
#   "What does adding '!' before wget accomplish in Jupyter Notebook?",
#   'Is there a way to use wget without checking certificates on MacOS?'],
#  '3ff703f7-c683-4193-8d3d-10bac8a1c93e': ['How can I set the backslash as an escape character in Git Bash for Windows?',
#   'What command allows me to use the backslash for escaping in Git Bash?',
#   'Is it necessary to add the escape sequence configuration to .bashrc in Git Bash for Windows?',
#   'What is the terminal command to configure backslashes as escape characters in Git Bash?',
#   'Can I configure Git Bash to use a backslash for escaping without modifying .bashrc?'],
#  '7fc6b586-5982-49c1-b947-1be1375bf554': ['How can I manage secrets in GitHub Codespaces?',
#   'What is the process to store secrets for GitHub Codespaces?',
#   'Where can I find instructions to handle secrets in Codespaces?',
#   'How do I ensure secrets are available in GitHub Codespaces?',
#   'Is there documentation for managing secrets in GitHub Codespaces?'],
#  'af694ff2-0ccb-4971-b15e-216b9c347850': ["What should I do when I can't connect to Docker daemon at the specified path?",
#   'How can I check if the Docker daemon is running properly?',
#   'Why might I be unable to connect to the Docker daemon on unix:///var/run/docker.sock?',
#   'What is a necessary command for updating WSL in PowerShell related to Docker issues?',
#   'How do I start the Docker daemon if I encounter connection issues?'],
#  '953f707a-b135-4bf4-b689-50a2b7b1f2b9': ['What should a Windows user do if they encounter an error related to Docker requiring elevated privileges?',
#   'How can I enable Hyper-V as the backend for Docker on Windows 10 Pro?',
#   'What is the alternative backend for Docker on Windows 10 Home, since Hyper-V is not available?',
#   'Where can detailed instructions be found for installing WSL2 on Windows 11?',
#   'What steps should be taken if an issue arises during WSL2 installation, specifically error 0x800701bc?'],
#  '3ad2596e-bf4f-480c-8cb9-c17461164fa2': ['Why am I receiving an access denied error when performing a docker pull for pgadmin4 from dbpage repository?',
#   "How should I fix the error 'repository does not exist or may require docker login' related to Docker image name?",
#   'Is a Docker login required to fetch public Docker images used in the Data Engineering Zoomcamp?',
#   "What should I do when encountering a 'permission denied' error for mounting volumes on macOS M1 with PostgreSQL Docker?",
#   'How can I resolve compatibility problems encountered when using Rancher Desktop for Docker on macOS M1?'],
#  'f42e4899-1903-4367-8dc0-75be9ef6a2b1': ['How do I delete a folder created by PostgreSQL in a Docker container with restricted permissions?',
#   'What is the command to forcefully and recursively remove a directory in Linux?',
#   "Why can't I delete a folder mounted to a Docker volume using the trash method?",
#   'Which user is likely to own a folder created by a PostgreSQL Docker container on my machine?',
#   'What steps should I take if my application cannot start due to a folder permission error from Docker?'],
#  '85096991-a14f-476e-8ba5-cd58a6927564': ["What should I do if Docker won't start on Windows 10/11?",
#   "How can I switch Docker containers if it's stuck on starting?",
#   'Do I need to enable Hyper-V to use Docker on Windows Pro?',
#   "How can I upgrade Docker if the menu option doesn't work?",
#   'Which backend options can I use for Docker on Windows 10/11 Pro Edition?'],
#  'f4cea97d-29a6-4b40-a4db-bd54c36a6929': ['Should Docker commands be executed from the Windows or a Linux file system in WSL?',
#   'What should I do if Docker remains stuck after configuring WSL2?',
#   'How can I make Docker work with Windows 10 Home Edition?',
#   'What is recommended for executing Docker commands on Windows?',
#   "What steps can I take if resetting Docker doesn't resolve the issue?"],
#  '76d3483e-ceaa-49a5-88de-8e31c4a7ad43': ['How should I store code for optimal file system performance on Windows using Docker?',
#   'Where can I find best practices for storing code in Docker on Windows?',
#   'Why is it recommended to use the default Linux distro for storing code with Docker?',
#   'What does Docker use by default for Windows 10 Home and Windows 11 Home users?',
#   'Where can I get more information about Docker best practices related to file storage?'],
#  '8187cf56-c92e-4e02-b5e1-46543ca279de': ["What should I do if I encounter the error 'the input device is not a TTY' when running Docker on Windows?",
#   "How can I resolve the 'input device is not a TTY' issue in Docker using mintty?",
#   'What command prefix can solve the TTY error in Docker on Windows?',
#   'How can I set up an alias to automatically use winpty with Docker commands on Windows?',
#   "What steps are needed to troubleshoot the 'input device is not a TTY' error before running Docker in mintty?"],
#  'e1dc0d9c-0a45-462d-804e-866e8d3c7bdf': ['What is a common issue when using pip install on a Docker container in Windows?',
#   'How can I address a temporary failure in name resolution when installing packages in Docker?',
#   'What might cause a connection error when running pip install inside a Docker container on Windows?',
#   'Can changing DNS settings help solve pip install issues in Docker containers, and how?',
#   'Is there a specific command that can help fix pip installation errors in a Windows Docker environment?'],
#  'ee33ddad-803a-4764-b077-c3a582a0c591': ['Why is the ny_taxi_postgres_data folder empty even after running the docker script?',
#   'What can I do if the ny_taxi_postgres_data is empty in VS Code on Windows?',
#   'How can I ensure the files are visible in the VS Code ny_taxi folder using Docker on Windows?',
#   'What is the correct way to set up the volume for PostgreSQL in Docker to see files in VS Code?',
#   'How does quoting the absolute path in the -v parameter solve the visibility issue in ny_taxi_postgres_data?'],
#  '3e883a89-f49b-4139-8ef9-4d0d9def0620': ['How do I set up Docker on a Mac?',
#   'Is there an updated method to install Docker on macOS?',
#   'Does the current licensing model affect Docker installation on Mac?',
#   'What is a reliable way to install Docker if previous methods are outdated?',
#   'Where can I download the Docker dmg file for macOS?'],
#  '9b5150d7-7d8d-4347-ae07-2f48549436df': ['What is a solution for the Docker permission error with /var/lib/postgresql/data directory?',
#   'How do you create a local Docker volume to map to the PostgreSQL data directory?',
#   'Which command verifies the working of Docker setup in WSL2?',
#   'What should you do if directory /var/lib/postgresql/data is not empty?',
#   'How do you check if dtc_postgres_volume_local is listed in Docker Desktop?'],
#  'ef970085-f0d0-4765-8ebf-f94bd8404774': ["How can I solve the 'invalid reference format' error when mounting volumes with Docker on Windows?",
#   "What are some alternative ways to replace the '-v' part on Windows for Docker volume mapping?",
#   'Is there a way to use quotes effectively to resolve volume mapping issues in Docker on Windows?',
#   "What should I do if Docker automatically creates a folder called 'ny_taxi_postgres_data;C' while mapping volumes on Windows?",
#   'How can I map volumes for Docker on Mac, and does it involve using quotes?'],
#  'a8c1a05b-fd1f-42ff-a31e-80234c5b95b0': ['What should I do if I encounter an error from the Docker daemon stating invalid mode with a path similar to \\Program Files\\Git\\var\\lib\\postgresql\\data?',
#   'How can I fix a Docker mounting path error related to the Git directory structure?',
#   'What is the correct way to define the Docker volume path for PostgreSQL data storage to avoid an invalid mode error?',
#   'How do I resolve a Docker error when the mounting path includes \\Program Files\\Git\\var\\lib\\postgresql\\data?',
#   'Is there an alternative mounting path I can use in Docker to avoid an invalid mode error concerning \\Program Files\\Git\\var\\lib\\postgresql\\data?'],
#  '810a55ec-9dd0-4a30-9bfd-1bdf59b203b9': ['What causes a file exists error when running a docker command a second time?',
#   'How should the docker run command be adjusted to avoid errors on the second execution?',
#   'What error indicates that a directory already exists when using Docker?',
#   'Why should the mount option be omitted after running a Docker command once?',
#   'What solution exists for a persistent directory error when using Docker with PostgreSQL?'],
#  '32414f42-3014-47a6-8ed8-6bfb72d5b6a4': ['What is the solution to the Docker build error related to checking context?',
#   'Why does the user id change in the ny_taxi_postgres_data directory cause issues?',
#   'How can I run the Docker build command to avoid permission issues?',
#   'Where can I find a more detailed explanation for the Docker build error?',
#   'What command should I use on Ubuntu to change directory permissions for Docker build?'],
#  '565f17c7-605b-45b3-8928-b1a6072a4a4f': ["How can I resolve the error 'context canceled' when running a Docker container?",
#   "What should I do if I encounter an error with the 'snap' command for Docker?",
#   'How do I check if Docker is installed through snap?',
#   "What does the error message 'unknown command status' indicate when using snap for Docker?",
#   'How can I fix the issue of port 5432 failing to bind in Docker?'],
#  'd02707a1-a149-4191-9845-7088174417c7': ["What is the cause of the build error related to can't stat ‘/home/fhrzn/Projects/…./ny_taxi_postgres_data’?",
#   'Why does the folder seem empty even though it is not in PopOS linux?',
#   'How can I resolve the authorization rights issue for a host folder in Docker?',
#   'What command should I use to give permission to everyone for a folder causing a build error?',
#   'Can you provide an example command to change folder permissions for Docker projects?'],
#  '0a153cc6-1c82-49a2-946d-bc0a92c2e809': ['What causes a permission denied error when reading a Dockerfile on Ubuntu/Linux?',
#   'How do I fix the permission denied error during Docker build on Ubuntu/Linux?',
#   'Why does Docker build raise an error due to permissions on a new folder?',
#   'What command grants write access to the owner for the Docker folder?',
#   "If 755 permissions don't resolve the Docker error, what should I try next?"],
#  'd8935560-aeb2-4934-a96d-2eec91b5b030': ['How can I find the name of a Docker network?',
#   'What command do I use to list Docker networks?',
#   'Where can I find the current Docker network name?',
#   'Is there a terminal command to display Docker networks?',
#   'How do I view all networks in Docker?'],
#  '7f678178-f673-4b96-86ca-a9ba0f0b3a95': ['What should I do if I see a conflict error with a container name in Docker?',
#   'How can I restart a Docker container without removing it?',
#   'What command should I use to stop a running Docker container?',
#   "How do I remove a Docker container that's causing a name conflict?",
#   'Is it necessary to remove a container to restart it in Docker?'],
#  '2164b7b4-d1d8-4140-acbc-a9f4a2234a26': ['What should I do if I encounter a host name translation error with docker-compose?',
#   "How can I resolve the error when the host name 'pgdatabase' is not recognized?",
#   'What is a common cause of the sqlalchemy.exc.OperationalError during database ingestion with Docker?',
#   'When using docker-compose up -d, how do I identify the correct network name for my script?',
#   "How do I determine the correct database name to use instead of 'pgdatabase' in Docker?"],
#  '9f7d416e-df75-47f9-9c11-11b1dcd87c22': ['How can I enable Docker installation on a VM using nested virtualization?',
#   'What commands should I run on an Intel CPU for setting up Docker in a VM on Linux?',
#   'How do I configure my Linux host to allow Docker installation on Windows 11 VM?',
#   'What is the solution for installing Docker on an AMD CPU VM with nested virtualization?',
#   'What steps are needed to enable nested virtualization on MacOS/Windows 11 VM in Linux?'],
#  '7d4c26e2-1e74-455e-a817-9016484f21c0': ['How can I manage Docker containers using VS Code?',
#   'What do I need to install in VS Code to work with Docker?',
#   'Can VS Code connect to Docker on WSL2?',
#   'Where can I find the Docker extension icon in VS Code?',
#   'What command is used to stop a Docker container?'],
#  '6b97243b-0480-4946-8cf9-b22178fc97c8': ["Why does my PostgreSQL container show 'Database directory appears to contain a database' in logs?",
#   'What should I do if my postgres container is not accepting any requests?',
#   "How can I resolve the 'server closed the connection unexpectedly' error with my PostgreSQL in Docker?",
#   'What does server termination abnormally mean when using Docker with PostgreSQL?',
#   'How can I address connection failure issues with my PostgreSQL database in Docker?'],
#  'a5c70aa8-846e-4b9a-a3b1-7150828dd62a': ["How can Docker be installed if it can't be installed directly on some Ubuntu versions?",
#   'What is an alternative method to install Docker on Ubuntu?',
#   'On certain Ubuntu versions, what command can be used to install Docker?',
#   'Is there a different way to set up Docker using the snap command on Ubuntu?',
#   'What steps are required to install Docker using snap on specific Ubuntu editions?'],
#  '59a073a1-0d1a-4c9d-9e24-230eb0aadd44': ['What should I do when I encounter a permissions error while changing the directory settings in Docker-Compose?',
#   'How do I inform the Docker-Compose file about a locally created Docker volume?',
#   "What command can I use to find the location of a Docker volume's mount point?",
#   'How can I fix the issue of Docker creating a new volume instead of using an existing one?',
#   'What is the correct sequence of actions if Docker-Compose creates a directory with an incorrect name?'],
#  '70df67f5-278c-4bfb-a9f6-5ee8738adbca': ['What should be checked if there is an error translating host name to address in Docker-Compose?',
#   'What command is used to start containers in detached mode?',
#   'How can you view the running containers in Docker?',
#   'What command allows you to view logs for a specific Docker container?',
#   "What should you do if 'docker ps' doesn't show pgdatabase running?"],
#  '98825763-5383-4b30-afc6-b9897e3e7ef3': ['What steps should I follow if I lose database data after running docker-compose up?',
#   "How can I resolve the error: could not translate host name 'pg-database' to address?",
#   'What should I check in the logs if Docker Compose creates its own default network?',
#   'How can I change the network name in my Ingestion script according to the logs?',
#   'What alternative tools can I use if I encounter problems with pgcli?'],
#  '907bb4c6-fe10-4ab6-82c2-a06a86c4dcce': ['What error might occur if Docker containers are not properly connected to a network?',
#   'How can I see all stopped and running Docker containers on my system?',
#   "What should I do if my server is unable to connect to the 'pg-database' host name?",
#   'Why is it recommended to avoid using dashes in host names within Docker Compose?',
#   'How can I specify a docker network for multiple containers in a docker-compose.yml file?'],
#  'd2243a46-2841-4e81-a3c3-111ab1581dc7': ['How can you ensure PGAdmin data persists when using docker-compose on GCP?',
#   'What is a common issue with postgres data persistence on GCP using docker-compose?',
#   'What change is needed in docker-compose to make PGAdmin data persistent on GCP?',
#   "Why might the path './pgadmin:/var/lib/pgadmin:wr' not work on GCP?",
#   'How do you configure Docker Volume for PGAdmin in docker-compose?'],
#  '04cc71ec-30ba-4097-956d-ca12cd2d646a': ['What should I do if the Docker engine stops unexpectedly and repeatedly crashes?',
#   'How can I resolve the issue of failing to fetch Docker extensions?',
#   'What steps can I take if Docker is not working even after a restart?',
#   'Is there a permanent solution if updating Docker does not fix the problem?',
#   'Do I need to re-fetch images if I decide to reinstall Docker to solve these issues?'],
#  '44967233-3da4-41c8-bcd9-648a2fbc9e4d': ['How do we persist pgAdmin configuration using Docker-Compose?',
#   'What section should we add to Docker-Compose for pgAdmin configuration persistence?',
#   'Which directory on the host does pgAdmin use for session storage in the container?',
#   'What command is necessary to grant write access for the pgAdmin container to the host folder?',
#   'Why is it important to set the right permissions for the pgAdmin_data directory before running docker-compose up?'],
#  '9a7829e9-e4a5-4b4b-8c79-94a320b6ba19': ["Why do I get 'permission denied' when using Docker-Compose?",
#   "What should I do if pgAdmin doesn't remember my previous database connection?",
#   'How can I let Docker-Compose access Docker without sudo?',
#   'What changes are needed in docker-compose.yaml to maintain pgAdmin state?',
#   'How do I create a volume for pgAdmin in Docker?'],
#  '5733c901-9360-48e9-afef-414c522449e4': ['Why is docker-compose still unavailable after editing .bashrc as instructed?',
#   'How should I resolve the issue with docker-compose not working on my Google Cloud VM?',
#   'What should I do if the docker-compose file downloaded is named differently from the expected command?',
#   'After the installation video, why is the downloaded file named docker-compose-linux-x86_64?',
#   'What name change is required for the docker-compose file to function correctly?'],
#  'ae03118d-3f63-4ce8-b57f-09885df1ae42': ['What command resolved the Docker-Compose credential error?',
#   'Where can I find more details on the Docker-Compose issue?',
#   'Which package must be installed to fix the credential error in Docker-Compose?',
#   'Can you direct me to a resource about resolving Buildkit issues with Docker-Compose?',
#   "What software installation helped resolve the Docker-Compose error while running 'up -d'?"],
#  '6ae692c5-8fb2-4afb-a02a-f81bc818ef0d': ['What should I do if I encounter errors related to docker-compose.yml and pgadmin setup?',
#   'How can I create a new volume on Docker for data persistence?',
#   'What changes should be made to the docker-compose.yml file to resolve issues?',
#   'How can I ensure successful data ingestion in Jupyter Notebook using Docker and pgadmin?',
#   'What server setup configurations should match between pgadmin and docker-compose.yml?'],
#  '9b0aaef3-f442-426e-880c-f17884209490': ["What should I do if I get an error about 'docker-credential-desktop' not found?",
#   'Where can I find the config.json file for Docker?',
#   'How can I fix the exec error related to Docker Compose and credentials?',
#   'What change should be made in the config.json to resolve the credential error?',
#   'What does modifying credsStore to credStore accomplish in fixing the error?'],
#  'e8296106-602c-418e-9b50-494de098f032': ['How can I determine which docker-compose version to download for WSL?',
#   'What command should I use to identify my system type for docker-compose installation?',
#   'How do I find the architecture flavor for downloading docker-compose in WSL?',
#   'Is there a direct command to download docker-compose for my WSL system?',
#   'Where can I find the releases for downloading docker-compose?'],
#  '1e448491-a8e6-4b43-92ec-9c0501664563': ['What might cause a service to refer to an undefined volume in Docker on Windows/WSL?',
#   'How can I resolve an error related to an undefined volume in docker-compose.yaml?',
#   'What should I add to my docker-compose file to fix an invalid compose project error?',
#   'Where should the volumes be included in the docker-compose structure to avoid errors?',
#   'If I mirror the docker-compose.yaml file from the video, what error could I encounter regarding volumes?'],
#  '8e2b70b3-69e4-4139-84cc-9e08b7eebd99': ['What is causing the WSL Docker directory permissions error?',
#   'How can Docker volumes resolve permission issues in WSL?',
#   "Is the 'user:' directive necessary when using Docker volumes with WSL?",
#   'What are the benefits of using Docker volumes in managing permissions between WSL and Windows?',
#   'Why is a local volume unnecessary for WSL Docker directory permissions error?'],
#  'aab8a915-b419-4903-a0e7-4802ebb21271': ['What should I use if pgadmin is not working for querying in Postgres?',
#   'Why might pgadmin fail to work on Windows with git bash or VM?',
#   'What libraries are required when encountering errors with pgadmin on Windows?',
#   'How can I avoid issues with pgadmin for querying in Postgres?',
#   'What package should I install to resolve issues with pgadmin?'],
#  '1d6875dc-317a-4057-887e-f14f621b1532': ["How can I resolve the error 'Insufficient system resources' with WSL?",
#   'What should I do if Windows Terminal is not updated and causing issues in Module 1?',
#   'How do I perform updates for Windows Terminal to fix resource errors?',
#   'What steps should I take to install Windows security updates that may fix WSL errors?',
#   'Why is it necessary to restart the system after updating apps and security?'],
#  '8e86b4f4-d6de-4dd6-bf00-06fee2110bba': ['Why does WSL integration with Ubuntu stop with exit code 1 out of the blue on Windows?',
#   'How can I fix a DNS issue causing WSL integration problems with Ubuntu on Windows?',
#   'What is the registry command to disable the DNS cache service temporarily on Windows?',
#   'How do I switch to Linux containers using Docker when facing WSL issues on Windows?',
#   'What should I do when the database is uninitialized and no superuser password is specified?'],
#  'e8741eea-56f7-4355-a1a3-1e301faea005': ['What might be causing an issue when running the GPC VM through SSH on WSL2?',
#   'How can I resolve a permissions issue when trying to execute an SSH command in WSL2?',
#   'What command can I use to change permissions for a private key SSH file on WSL2?',
#   'How do I create a .ssh directory in the home directory of WSL2 and copy the content from the Windows .ssh folder?',
#   'What steps can be taken if WSL2 is not looking for .ssh keys in the correct folder?'],
#  'dfeb0367-d5a5-4bdd-a794-b58d5d13fab3': ['Why might WSL2 not resolve a host name correctly?',
#   'What could be a reason for WSL2 failing to find the correct .ssh/config path?',
#   'How can I resolve the host name issue in WSL2 by configuring SSH?',
#   'Where should I create the SSH config file in WSL2 to resolve host problems?',
#   'What details need to be in the .ssh/config file to link to GPC VM in WSL2?'],
#  '90302ca9-8c02-4aeb-92d0-fcb5e1be6ddd': ['What should I do if PGCLI connection on port 5432 is refused?',
#   'How can I resolve the issue with PGCLI connection failure due to SSL negotiation packet error?',
#   'What command should I use to connect to PostgreSQL when facing a connection refused error?',
#   'If I encounter a connection failure with PGCLI, what host and port settings are recommended?',
#   "What steps can I take if PGCLI can't connect because it failed to receive data from the server?"],
#  'd32fac79-625b-40bd-b4cb-6e871f59516f': ['What could be causing a PGCLI --help error?',
#   'Why might PGCLI --help not work correctly?',
#   'How can I troubleshoot a PGCLI --help issue?',
#   'What should I do if I get an error with PGCLI --help?',
#   'What steps can I take when facing a PGCLI --help error?'],
#  'eb880dc7-debd-4590-a05f-cf5f12d1c333': ['Can we use pgcli on our machine without extra containers?',
#   'Is it necessary to run pgcli within a new Docker container?',
#   'How do we connect to postgres with pgcli in this course?',
#   'Do we need a container for pgcli access to postgres?',
#   'Should pgcli be installed on the local system to access the database?'],
#  'f862ae3f-eb20-4217-92d0-60e08b61ef9f': ["What steps should I follow if PGCLI reports a password authentication failure for user 'root' due to an existing Postgres installation?",
#   'How can I configure Docker to use a different port and avoid conflicts with a local Postgres installation?',
#   'What command do I need to run to connect to the Postgres Docker container using a different port with pgcli?',
#   'How can I identify which application is blocking my local Postgres port on MacOS?',
#   'What commands should I use to stop and start the PostgreSQL service running on MacOS?'],
#  'b91c465b-797c-4b56-87ba-c11457cc3e3f': ['What error do I get when running pgcli without proper permissions?',
#   "How can I fix a PermissionError in pgcli related to '.config/pgcli'?",
#   'What should I avoid using when installing pgcli to prevent permissions issues?',
#   'What is the recommended tool for installing pgcli without affecting the system python?',
#   "What alternative solutions are suggested if conda install is stuck at 'Solving environment'?"],
#  '4967fae3-18cf-49a8-9173-887e7e1d72d9': ['What is the error message received when there is no pq wrapper available?',
#   'How can I solve the ImportError related to psycopg?',
#   'What Python version is required to avoid issues with psycopg2-binary installation?',
#   'Which command helps create a new conda environment with Python 3.9?',
#   'How should pgcli be installed to connect to a PostgreSQL database?'],
#  '021b48a1-e9b2-4988-8fb7-09ad442577db': ['How can I resolve being stuck on the password prompt in PGCLI for postgres?',
#   "What should I do if I face password authentication failure for user 'root' in PGCLI on Windows?",
#   'Can I fix PGCLI connection failure by uninstalling Postgres 12 from Windows?',
#   'How can I change the port of the docker container to solve connection issues?',
#   'What is the new solution for fixing PGCLI connection failure after closing the Postgres:13 connection?'],
#  'bfeb8b1d-8b2b-4e92-bf44-a4657f6fab88': ['What should I do if my terminal cannot recognize the pgcli command after installation?',
#   'How can I add the necessary path for pgcli to my Windows system?',
#   'Where might Python be installed if it is not in the default location?',
#   'Which command helps me find where pgcli is installed?',
#   'What needs to be replaced in the Python path to make pgcli work?'],
#  '42de9cff-b3a8-447b-b8df-135d558f111d': ['How can I use pgcli without installing it locally?',
#   'What command should I use to run pgcli in a Docker container?',
#   'What are the necessary postgres related variables for pgcli in Docker?',
#   'How do I specify the hostname and username when running pgcli in Docker?',
#   'What is the command output when checking the database schema in pgcli?'],
#  '18687ef6-e06d-42d9-8fde-66fbe1b14a22': ['Why is PULocationID not recognized in PGCLI?',
#   'How should columns with capital letters be handled in PGCLI?',
#   'What is the rule for localidentifiers in PGCLI regarding case sensitivity?',
#   'Why is it necessary to use quotations for column names in PGCLI?',
#   'What happens if I don’t use quotations around capitalized columns in PGCLI?'],
#  'ff7413de-40f5-4ac5-a550-95f9425aece8': ["What should I do if I encounter the error message 'column c.relhasoids does not exist' in PGCLI?",
#   "How can I resolve the error where the database 'ny_taxi' does not exist in PGCLI?",
#   "What steps are needed to fix the 'c.relhasoids does not exist' error in the context of PGCLI?",
#   "If I face an issue with PGCLI showing 'database not exist', what's the recommended solution?",
#   "How do I troubleshoot the 'column c.relhasoids does not exist' error in PGCLI with relation to the command '\\d <database name>'?"],
#  'ff354def-361b-4b0d-ab14-23f2328ef4d8': ["How do I resolve a password authentication error for user 'root' when connecting to Postgres on localhost?",
#   'What should I do if port 5432 is already taken by another Postgres instance on my machine?',
#   'Why might I encounter an OperationalError when uploading data via a connection in a Jupyter notebook?',
#   "What steps should I take if changing the port number doesn't resolve the Postgres connection issue?",
#   'How can I check if a Windows service is causing a conflict with my Postgres Docker connection?'],
#  'd3e3df5e-9d02-46de-9088-c719621b20a5': ["How do I resolve a psycopg2.OperationalError indicating the role 'root' does not exist when connecting to Postgres on localhost?",
#   "What are the steps to troubleshoot a failed connection to a Postgres server at port 5432 due to a missing 'root' role?",
#   "How can changing the port number help with a psycopg2.OperationalError related to Postgres role 'root'?",
#   'What command should I run within a Docker container to verify if a root user can log in to Postgres?',
#   "What alternative solutions exist for resolving the role 'root' does not exist error in a Docker Compose environment with Postgres?"],
#  '586e31b0-5f1a-4da3-9ad5-7c1d607342dc': ["Why does psycopg2 show an OperationalError when trying to connect to the 'ny_taxi' database?",
#   'How can I confirm that my postgres instance is running through Docker?',
#   'What is a possible solution if I have a pre-installed postgres software causing port conflicts?',
#   'Which port should I use to avoid conflicts with existing postgres installations?',
#   'What is the recommended command to check running Docker containers?'],
#  'eb00a7bf-2c86-42c0-bb6e-96bfde50cc74': ["How do I resolve the ModuleNotFoundError for 'psycopg2' while using Postgres?",
#   "What should I do if updating psycopg2-binary doesn't fix the module error?",
#   "Can updating conda solve the 'ModuleNotFoundError' issue for psycopg2?",
# ...
#   'Should I follow the video or the notebook for Module 4?',
#   'Who provided the note regarding the end state of the video?',
#   "What should I do if I'm confused about the video and notebook integration?"],
#  'ac4c273c-90c5-40dd-9e3a-73c73d557848': ['How can I pass AWS credentials to my Docker image if my Python script is not reading them correctly?',
#   'What is the correct order to pass environment variables when using the docker run command?',
#   'How can I map my AWS credentials files into a Docker container?',
#   'What does the AWS SDK and CLI check for if credentials are not provided through environment variables?',
#   'Who provided the solution for passing environment variables correctly in the course record?'],
#  '715851d1-ed49-436f-92b0-beb6350f3972': ['What command should I use to troubleshoot and list the model in the docker container app/ directory?',
#   'How do I build a new Docker image from the svizor/zoomcamp-model:mlops-3.10.0-slim image?',
#   'What is the purpose of the CMD command in the Dockerfile?',
#   'How can I copy files like a requirements file into the Docker container?',
#   'What needs to be done every time the Dockerfile is changed before running a container?'],
#  'f0cd0e47-8b36-4a10-a012-d1d21384d7dd': ['How can I ensure my Docker image matches the host platform?',
#   'What should I do if my Docker image platform does not match my host platform?',
#   'How do I fix platform issues when building a Docker image?',
#   'What command ensures a Docker image is built for the correct platform?',
#   'What tag should I use to resolve platform mismatch in Docker?'],
#  '718203dd-17c6-4c05-9fc1-af947e07486c': ['What should I do if I encounter an HTTP Error 403 Forbidden in score.ipynb when using apply_model?',
#   'How can I fix the HTTPError 403 issue in the apply_model function in Module 4?',
#   'What URL should I use to prevent an HTTPError 403 when applying the model?',
#   "Why am I getting a 403 Forbidden error when using f'https://s3.amazonaws.com/nyc-tlc/trip+data/' in Module 4?",
#   'Who can I contact for help with HTTPError issues in score.ipynb?'],
#  '656d95d5-1107-4310-970e-b520fa590879': ["How do I resolve ModuleNotFoundError for 'pipenv.patched.pip._vendor.urllib3.response'?",
#   "What command should I use to fix the error with 'pipenv.patched.pip._vendor.urllib3.connectionpool.py'?",
#   'What solution is there for ModuleNotFoundError related to urllib3 in pipenv?',
#   'Which pip command do I use to solve the error in urllib3 connectionpool?',
#   'If I encounter a ModuleNotFoundError with pipenv and urllib3, what should I do?'],
#  '34af9b06-8a93-4b4c-a911-ca71e136489b': ['What default credentials do we use if a login window appears while accessing Grafana through localhost?',
#   'If prompted for a username and password in Grafana after running docker-compose up, what should be entered?',
#   'Where can I find help if Grafana asks for login details after executing docker-compose up?',
#   'What are the default login credentials for Grafana when set up as demonstrated in video 5.2?',
#   'What should be done if Grafana requests a username and password upon first access when following the video instructions?'],
#  '0f74eb59-dea0-42c2-adc5-42e56b91d5b9': ['What command error occurs when using docker compose up --build in Linux from video 5.2?',
#   'How can I resolve the issue with services not starting in Linux using docker compose?',
#   'What is the correct command sequence to start services in Linux for Module 5?',
#   'Why do I get an unknown flag error when following video 5.2 instructions?',
#   'What adjustment is needed for starting services in Linux using docker-compose?'],
#  '24630597-79cc-470e-b36a-d63d08eafa02': ['What solution resolves KeyError ‘content-length’ in prepare.py?',
#   'How can one fix the KeyError issue encountered in prepare.py?',
#   "What steps should be taken if prepare.py encounters a KeyError with 'content-length'?",
#   'How was the link in prepare.py adjusted to fix the KeyError problem?',
#   'What adjustment in prepare.py can resolve downloading issues along with KeyError?'],
#  'ebad3e73-c5ad-49bc-8ed0-f8e5ef8eea3b': ['What error occurs when sending data to the real-time prediction service with evidently?',
#   "How do I resolve the 'Max retries exceeded with url: /api' error for the evidently service?",
#   'Why does my evidently service exit with code 2 during execution?',
#   'What are the potential solutions to fix the import error from pyarrow in evidently?',
#   'What did Surawut Jirasaktavee suggest to do if pyarrow is unused in app.py for evidently?'],
#  '9e805409-c106-410c-9723-5a14999f3c92': ['What should I do if I encounter a ValueError related to metrics in Module 5?',
#   'How can I resolve the error about incorrect item in Report with evidently?',
#   'Why am I getting a ValueError with my metrics in Monitoring module?',
#   'What is the solution for the error when a metric preset is missing in a Report?',
#   "How do parentheses relate to resolving an error in Module 5's Report function?"],
#  'ba348c65-7f06-4ac4-b56c-65ee857f7878': ['How to resolve an error when using RegressionQualityMetric()?',
#   'What should be added when using RegressionQualityMetric()?',
#   'How to ensure RegressionQualityMetric() works correctly?',
#   'What is required in current_data for RegressionQualityMetric()?',
#   'What causes errors in RegressionQualityMetric() usage?'],
#  '1524fcac-56c6-470a-bfd7-f413c6696dd3': ["What does a ValueError indicating 'array with 0 sample(s)' mean in Module 5?",
#   'How can I resolve an empty training dataset issue in the monitoring module?',
#   'Why do I encounter a ValueError with LinearRegression in the course?',
#   'What causes the generated data to result in an empty array in the example given?',
#   'How should I adjust the datetime to ensure the training dataset is not empty?'],
#  '3efdb1d1-0e6c-401c-8d73-1692a0653841': ["What should I do when I encounter 'target columns' errors after adding a metric?",
#   "How can I resolve 'prediction columns' not present errors when adding a metric?",
#   'Which documentation should I consult about the requirements for adding a metric?',
#   'Can you give an example of a metric that doesn’t require parameters for evaluating feature correlations?',
#   'Who provided the solution for errors encountered when adding a new metric?'],
#  '9b00f25b-c8f6-4633-9f1b-0a0ff0cfc1c8': ["What should I do if I can't log into Grafana using default credentials?",
#   'How can I fix login issues in Grafana with default user and password?',
#   "What is the solution when Grafana's standard admin login fails?",
#   'How do I resolve an error when trying to log into Grafana with admin/admin?',
#   'What command can reset the Grafana password if standard login fails?'],
#  'd12f55c2-d8f2-4d85-bc1f-96beaf8721ee': ['What should I check if my Grafana chart is not updating?',
#   'How can I make sure my Grafana chart refreshes frequently?',
#   'What timezone settings should I consider for Grafana updates?',
#   'Why might my metric generation script not reflect in Grafana charts?',
#   'How can adjusting the refresh interval affect Grafana chart updates?'],
#  '4c1d85fa-9e43-42f6-810b-9c11dbb27a53': ["What command did you try when the Prefect server wasn't running locally?",
#   'What solution did Erick Calderin resort to for running the script?',
#   'How did you address the issue with the Prefect server stopping immediately?',
#   'Where did you report the Prefect server issue?',
#   'Which platform did you use to run the script as an alternative?'],
#  '03307a74-4108-4068-95c3-38d018691d1a': ['What should I do if I encounter a no disk space left error during docker compose up?',
#   'How can I remove unused Docker resources to free up space?',
#   'What command can I use to see what’s taking up space in Docker?',
#   "How do I resolve the issue when there's no disk space left while using Docker?",
#   'Who provided the solution for the no disk space left error in Docker compose up?'],
#  'a0c343bb-219d-4444-96b0-eca4fa56c43a': ['What error appears when trying to listen on port 8080 using Docker?',
#   'How can I resolve the php_network_getaddresses error in Docker Compose?',
#   'Where should I add the command to fix the address family issue in Docker?',
#   'What specific command needs to be added in the adminer block?',
#   'Who provided the solution to this Docker issue?'],
#  '20c4e4d5-507f-446c-b552-a6289e9b6abe': ['How can I create Evidently-like charts in Grafana?',
#   'What is required to design custom plots in Grafana like Evidently?',
#   'Is there a Grafana plug-in needed for scatter plot panels?',
#   'How can I export data from Evidently for external visualizations?',
#   'Why is the specific Evidently plot useful during debugging?'],
#  'cde598b2-3b51-4bd5-8aaa-cde7167ea3c6': ["What should I do if I get an error about 'Unable to locate credentials' after running localstack with kinesis?",
#   "How can I resolve the 'Unable to locate credentials' error from the print statement in test_docker.py?",
#   'What environment variables should I add to docker-compose.yaml to fix a credentials error with localstack and kinesis?',
#   "Is there an alternative method to fix the 'Unable to locate credentials' error besides modifying docker-compose.yaml?",
#   'Which random values can be used for AWS credentials when configuring via AWS CLI with localstack?'],
#  '5c91cfbd-00ad-45cc-b558-e9cd8d407917': ['How can I resolve an error when creating a bucket with boto3 in a specific region?',
#   "What does the error 'unspecified location constraint is incompatible' mean during bucket creation with localstack?",
#   'What modification should I make in the create_bucket call to fix the IllegalLocationConstraintException?',
#   'How should I properly create an S3 bucket with localstack to avoid a client error?',
#   'What parameter needs to be added when using boto3 to create a bucket in a specific AWS region?'],
#  '377a0497-9a17-4c71-ba88-e3cb2a4a82a1': ['What can cause the error with the AWSRequest object in AWS CLI?',
#   'How do I resolve errors when running AWS CLI commands like aws s3 ls?',
#   'What environment variables should I set to fix the AWSRequest object error?',
#   'Do the values for AWS CLI environment variables matter when fixing the error?',
#   'Who contributed the solution to the AWS CLI error in this module?'],
#  'ba0cf824-3eaf-4070-aadc-4cea07bc771d': ['What should I check in .pre-commit-config.yaml if I receive a mapping values error?',
#   'Why does the pre-commit error occur related to mapping values?',
#   'How can I resolve the pre-commit hooking issue that triggers an error on every commit?',
#   'What is the role of 4 spaces in front of the `repo` in .pre-commit-config.yaml?',
#   'Who contributed the solution for fixing the pre-commit error in Module 6?'],
#  '453c49ae-243e-4709-854e-0701c418b3d1': ['How can I reset pytest configurations after using a previous testing folder?',
#   'What should I do if pytest configurations persist after changing folders?',
#   'Is there an option to completely remove pytest test configurations?',
#   'How do I remove any remnants of previous pytest test settings?',
#   'Can you guide me on undoing pytest setup in a folder after testing?'],
#  '21aa36b2-88c7-4341-aff8-b0a1c5070ba1': ['What is the solution for empty records in Kinesis using LocalStack mentioned in Module 6?',
#   'When following video 6.3, at which minute does the issue with Kinesis get-records occur?',
#   'What command option resolves the issue with empty records in Kinesis get-records?',
#   'In resolving the Kinesis get-records issue, what endpoint URL is used in the command?',
#   'Which specific module and section of the course discusses problems with Kinesis Get Records and LocalStack?'],
#  '19f60a63-91d9-481b-aa6e-8a2ea60c9a18': ['What error might occur when executing git commit related to utf-8 encoding in Powershell?',
#   'How can I fix the utf-8 encoding error in the git pre-commit yaml file?',
#   'What command should I use to correctly set the utf-8 encoding for the pre-commit yaml file?',
#   'Who provided the solution for the utf-8 encoding error in Powershell git commits?',
#   'Which file is mentioned in the InvalidConfigError when encountering an encoding problem?'],
#  '81858f09-ab67-474c-b7f2-3b1168b2c445': ['What error occurs when a git commit with a pre-commit hook is attempted?',
#   "How can I resolve an issue with the 'PythonInfo' object lacking 'version_nodot'?",
#   'What is the return code when an unexpected error occurs during git commit?',
#   'What is the first step to take when receiving a CalledProcessError during pre-commit?',
#   'Who contributed the solution for the git commit error in the FAQ?'],
#  'b1146d45-748a-4151-a6da-36f2293cb56e': ["What issue might occur when running pytest if you've used custom packages?",
#   "How can the 'No module named production' error be resolved during pytest execution?",
#   'Why does pytest fail when executed from a specific directory with custom package imports?',
#   'What command should be used to execute pytest to avoid module not found errors?',
#   "Why is 'python -m pytest' recommended over directly running pytest for tests?"],
#  '22c7a628-9119-476b-b111-31038c03e74f': ['What is the problem that occurs with pytest when using pre-commit hooks and custom packages?',
#   "How should the project be restructured to resolve the 'No module named production' error?",
#   'What modifications need to be made to the pytest-check hook to prevent the module not found error?',
#   'What should the run.sh script do to ensure pytest works correctly with pre-commit hooks?',
#   'Who provided the solution for the pytest error in pre-commit hooks?'],
#  'ef1dc158-164b-41e8-82e5-d64c8651fd7b': ['Why do I encounter a permission error with GitHub Actions when running a script?',
#   'What causes a process to complete with error code 126 on GitHub?',
#   'How can I solve a permission denied error when executing a script in a CI workflow?',
#   'What command allows you to add execution permission to a script for GitHub CI?',
#   'Who provided the solution for the execution permission error in the FAQ record?'],
#  '36450a5f-b1ff-427c-b908-6a243fe96e18': ['How can resource usage be minimized when running multiple Docker containers with docker-compose?',
#   'What is the solution to select a specific group of containers in a large docker-compose file?',
#   'Which option should be added to the service definition to manage multiple Docker containers efficiently?',
#   'What command modification is required to start services using specific profiles in Docker?',
#   'Who contributed the solution for managing multiple Docker containers using profiles?'],
#  'b9691365-8d76-4d7f-bb59-330249c032a8': ['What should I verify if my integration tests and Kinesis are problematic?',
#   'How can I create a stream in the right AWS region with docker-compose?',
#   'Why is it important for AWS regions to align in docker-compose and config files?',
#   'What region setting should be configured in ~/.aws/config for proper setup?',
#   'Could mismatched AWS regions between config and docker-compose affect stream creation?'],
#  '736b28a2-befa-4025-8828-b2de7566332d': ['What should be done if the pre-commit command fails with isort?',
#   'Who provided the solution for the isort pre-commit issue?',
#   'What version of isort should be set to resolve the pre-commit failure?',
#   'Which module discusses best practices involving the isort pre-commit command?',
#   'How was the isort pre-commit issue addressed as per Module 6?'],
#  '807e0c8e-7e8f-4cd9-aebe-745856e14f00': ['How can I remove infrastructure set up via GitHub Actions in Module 6?',
#   'What is the process to delete AWS resources created using CD-Deploy Action?',
#   'Can you explain the steps to destroy infrastructure from a local machine that was created through GitHub?',
#   'What commands are needed to terminate cloud infrastructure using Terraform when deployed via GitHub Actions?',
#   'How should I handle the destruction of AWS infrastructure initiated through GitHub Actions in Module 6?']}
